# %%
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('land_train.csv')

# %%
train_df.head()
# Out:
#     X1   X2   X3   X4   X5   X6        I1        I2        I3        I4  \
# 0  323  229  120  517  209  115  0.623234 -1.047476  1.473405  0.380537
# 1  335  220  109  387  149   89  0.560484 -1.004514  1.200777  0.324813
# 2  255  150   52  184   72   45  0.559322 -0.996822  0.825000  0.300728
# 3  254  182   73  413  156   84  0.699588 -1.151258  1.425354  0.436268
# 4  257  219  100  722  254  130  0.756691 -1.236199  1.990973  0.506155
#
#          I5        I6  target
# 0 -0.021277  0.424242       1
# 1 -0.101010  0.444030       1
# 2 -0.072165  0.437500       1
# 3  0.070064  0.451670       1
# 4  0.130435  0.479508       1

# %%
train_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110000 entries, 0 to 109999
# Data columns (total 13 columns):
# X1        110000 non-null int64
# X2        110000 non-null int64
# X3        110000 non-null int64
# X4        110000 non-null int64
# X5        110000 non-null int64
# X6        110000 non-null int64
# I1        110000 non-null float64
# I2        110000 non-null float64
# I3        110000 non-null float64
# I4        110000 non-null float64
# I5        110000 non-null float64
# I6        110000 non-null float64
# target    110000 non-null int64
# dtypes: float64(6), int64(7)
# memory usage: 10.9 MB

# %%
train_df.describe()
# Out:
#                   X1             X2             X3             X4  \
# count  110000.000000  110000.000000  110000.000000  110000.000000
# mean      505.820582     778.290627     819.375336    1752.844418
# std       428.347173     529.490028     674.422188     693.583645
# min         0.000000      79.000000       0.000000      77.000000
# 25%       172.000000     333.000000     211.000000    1209.000000
# 50%       540.000000     809.500000     817.000000    1785.000000
# 75%       699.000000    1022.000000    1237.000000    2148.000000
# max      9346.000000    9615.000000    9877.000000    9316.000000
#
#                   X5             X6             I1             I2  \
# count  110000.000000  110000.000000  110000.000000  110000.000000
# mean     1078.027418     739.470318       0.384085      -0.712814
# std       868.842300     797.061740       0.387576       0.472998
# min        52.000000      25.000000      -0.517672      -1.566332
# ...

# %%
x = range(12)
y = train_df.describe().values[2,:-1]
plt.scatter(x,y)
plt.title('Training Set Variances')
# Out:
# Text(0.5,1,'Training Set Variances')

# %%
test_df = pd.read_csv('land_test.csv')

# %%
test_df.head()
# Out:
#     X1   X2    X3    X4    X5    X6        I1        I2        I3        I4  \
# 0  338  554   698  1605  1752  1310  0.393834 -0.350045  1.565423  0.311659
# 1  667  976  1187  1834  1958  1653  0.214167 -0.181467  1.050679  0.196439
# 2  249  420   402  1635  1318   736  0.605302 -0.712650  2.268984  0.441984
# 3  111  348   279  1842   743   328  0.736917 -1.162062  3.074176  0.551699
# 4  349  559   642  1534  1544   989  0.409926 -0.406678  1.607795  0.323984
#
#          I5        I6
# 0  0.304781 -0.043789
# 1  0.164085 -0.032700
# 2  0.293497  0.107348
# 3  0.080725  0.425145
# 4  0.212753 -0.003249

# %%
test_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 12 columns):
# X1    2000000 non-null int64
# X2    2000000 non-null int64
# X3    2000000 non-null int64
# X4    2000000 non-null int64
# X5    2000000 non-null int64
# X6    2000000 non-null int64
# I1    2000000 non-null float64
# I2    2000000 non-null float64
# I3    2000000 non-null float64
# I4    2000000 non-null float64
# I5    2000000 non-null float64
# I6    2000000 non-null float64
# dtypes: float64(6), int64(6)
# memory usage: 183.1 MB

# %%
test_df.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06
# mean   4.200374e+02  6.354340e+02  7.138399e+02  1.792880e+03  1.743670e+03
# std    1.456850e+02  1.600032e+02  2.477531e+02  4.005526e+02  5.307883e+02
# min    3.000000e+00  1.000000e+02  6.700000e+01  1.740000e+02  5.100000e+01
# 25%    3.120000e+02  5.220000e+02  5.220000e+02  1.536000e+03  1.393000e+03
# 50%    4.090000e+02  6.210000e+02  6.970000e+02  1.804000e+03  1.706000e+03
# 75%    5.110000e+02  7.310000e+02  8.790000e+02  2.042000e+03  2.073000e+03
# max    2.667000e+03  3.479000e+03  3.998000e+03  5.122000e+03  5.942000e+03
#
#                  X6            I1            I2            I3            I4  \
# count  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06
# mean   1.193628e+03  4.282912e-01 -4.530533e-01  1.806317e+00  3.292207e-01
# ...

# %%
x = range(12)
y = test_df.describe().values[2,:]
plt.scatter(x,y)
plt.title('Test Set Variances')
# Out:
# Text(0.5,1,'Test Set Variances')
